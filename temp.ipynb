# %%
from inverse_modelling_tfo.visualization.visualize import plot_error_distribution, plot_performance_distributions
from model_trainer.custom_models import PerceptronBD
from model_trainer import RandomSplit
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'x' : np.random.rand(100),
    'y' : np.random.rand(100)    
})
y_scaler = StandardScaler()
data['y'] = y_scaler.fit_transform(data[['y']])

model = PerceptronBD([1, 2, 1])
validation_method = RandomSplit(0.8)
_ = plot_performance_distributions(data, ['x'], ['y'], y_scaler, model, validation_method=validation_method)
