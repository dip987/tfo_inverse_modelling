# %%
from pathlib import Path
import pandas as pd

raw_data_path = Path(r'/home/rraiyan/simulations/tfo_sim/data/compiled_intensity/synthetic_ppg_base.pkl')
# raw_data_path = Path(r'/home/rraiyan/simulations/tfo_sim/data/compiled_intensity/pencil2.pkl')
data = pd.read_pickle(raw_data_path)
data.groupby("SDD")["Intensity"].describe()
# Out:
#         count          mean            std           min           25%  \
# SDD
# 10   167400.0  2.077815e+06  727054.000000  9.041139e+05  1.413112e+06
# 15   167400.0  2.569029e+05  141760.546875  6.102120e+04  1.311111e+05
# 19   167400.0  5.449162e+04   39634.492188  7.789273e+03  2.064744e+04
# 24   167400.0  9.483078e+03    9183.846680  8.166035e+02  2.384339e+03
# 28   167400.0  2.211983e+03    2811.979004  1.176075e+02  3.531439e+02
# 33   167400.0  5.213066e+02     924.985779  1.433735e+01  4.632700e+01
# 37   167400.0  1.562964e+02     381.898743  1.896245e+00  6.744018e+00
# 41   167400.0  5.982554e+01     185.911606  2.582360e-01  1.051362e+00
# 46   167400.0  2.709465e+01      98.956314  2.901628e-02  1.629740e-01
# 50   167400.0  1.458419e+01      57.088810  3.746766e-03  3.900728e-02
# 55   167400.0  8.287659e+00      33.951626  3.289235e-04  5.706369e-03
# 59   167400.0  4.840719e+00      20.311699  3.387658e-05  9.531678e-04
# ...

# %%
data['Maternal Hb Concentration'].unique()
# Out:
# array([11., 12., 13., 14., 15.])

# %%
processed_data = pd.read_pickle(Path(r'/home/rraiyan/personal_projects/tfo_inverse_modelling/data/processed_data/sythentic_ppg_base.pkl'))
